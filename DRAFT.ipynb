# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.distance import great_circle
from tqdm import tqdm

# %%
hdb_df = pd.read_csv('data/hdb_coordinates_final.csv', low_memory=False)

# %%
hdb_clean = pd.read_csv('data/hdb_combined_clean.csv', low_memory=False)

# %%
hdb_df = hdb_df.drop(hdb_df.columns[0], axis=1)
hdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919408 entries, 0 to 919407
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   town                 919408 non-null  object
#  1   flat_type            919408 non-null  object
#  2   block                919408 non-null  object
#  3   street_name          919408 non-null  object
#  4   storey_range         919408 non-null  object
#  5   floor_area_sqm       919408 non-null  float64
#  6   flat_model           919408 non-null  object
#  7   lease_commence_date  919408 non-null  int64
#  8   resale_price         919408 non-null  float64
#  9   remaining_lease      210358 non-null  object
#  10  address              919408 non-null  object
#  11  latitude             919408 non-null  float64
#  12  longitude            919408 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 91.2+ MB

# %%
hdb_df['storey_range'].unique()
# Out:
# array(['10 TO 12', '04 TO 06', '07 TO 09', '01 TO 03', '13 TO 15',
#        '19 TO 21', '16 TO 18', '25 TO 27', '22 TO 24', '28 TO 30',
#        '31 TO 33', '40 TO 42', '37 TO 39', '34 TO 36', '06 TO 10',
#        '01 TO 05', '11 TO 15', '16 TO 20', '21 TO 25', '26 TO 30',
#        '36 TO 40', '31 TO 35', '46 TO 48', '43 TO 45', '49 TO 51'],
#       dtype=object)

# %%
hdb_clean['storey_median'].unique()
# Out:
# array([11,  5,  8,  2, 14, 20, 17, 26, 23, 29, 32, 41, 38, 35,  3, 13, 18,
#        28, 33, 47, 44, 50], dtype=int64)

# %%
hdb_df['year'] = hdb_df['month'].str[:4].astype(int)

# %%
hdb_df[hdb_df['lease_commence_date'] > hdb_df['year']].head()
# Out:
#          month           town  flat_type block          street_name  \
# 23271  1991-11         BISHAN     4 ROOM   227         BISHAN ST 23
# 34246  1992-08       TAMPINES     5 ROOM   476       TAMPINES ST 44
# 46535  1993-06      WOODLANDS     5 ROOM   321      WOODLANDS ST 32
# 69033  1994-05  CHOA CHU KANG  EXECUTIVE   528  CHOA CHU KANG ST 51
# 69609  1994-05      PASIR RIS     4 ROOM   631       PASIR RIS DR 3
#
#       storey_range  floor_area_sqm flat_model  lease_commence_date  \
# 23271     04 TO 06           103.0    MODEL A                 1992
# 34246     04 TO 06           132.0    MODEL A                 1993
# 46535     01 TO 03           127.0   IMPROVED                 1994
# 69033     07 TO 09           153.0  APARTMENT                 1995
# 69609     10 TO 12           104.0    MODEL A                 1995
#
#        resale_price remaining_lease                  address  latitude  \
# 23271      135000.0             NaN         227 BISHAN ST 23  1.358071
# 34246      200000.0             NaN       476 TAMPINES ST 44  1.361113
# 46535      145000.0             NaN      321 WOODLANDS ST 32  1.431886
# 69033      350000.0             NaN  528 CHOA CHU KANG ST 51  1.392412
# 69609      160000.0             NaN       631 PASIR RIS DR 3  1.378890
#
#         longitude  year
# 23271  103.847138  1991
# 34246  103.953548  1992
# 46535  103.779323  1993
# 69033  103.741549  1994
# 69609  103.940140  1994

# %%
hdb_df = hdb_df[hdb_df['lease_commence_date'] <= hdb_df['year']]

# %% [markdown]
# ## Amenities

# %%
schools_df = pd.read_csv('data/schools_address.csv')
schools_df = schools_df.drop(schools_df.columns[0], axis=1)
schools_df.head()
# Out:
#                       school_name                  address  postal_code  \
# 0        ADMIRALTY PRIMARY SCHOOL    11   WOODLANDS CIRCLE       738907
# 1      ADMIRALTY SECONDARY SCHOOL  31   WOODLANDS CRESCENT       737916
# 2    AHMAD IBRAHIM PRIMARY SCHOOL    10   YISHUN STREET 11       768643
# 3  AHMAD IBRAHIM SECONDARY SCHOOL     751  YISHUN AVENUE 7       768928
# 4                  AI TONG SCHOOL   100  Bright Hill Drive       579646
#
#                    mrt_desc  \
# 0         Admiralty Station
# 1             ADMIRALTY MRT
# 2                    Yishun
# 3  CANBERRA MRT, YISHUN MRT
# 4                Bishan MRT
#
#                                             bus_desc  latitude   longitude
# 0                                 TIBS 965, 964, 913  1.442635  103.800040
# 1                                                904  1.445891  103.802398
# 2  Yishun Ring Road - 812 (white plate); Yishun A...  1.433153  103.832942
# 3  117, 167, 169, 800, 811, 812, 883, 856, 858, 8...  1.436060  103.829719
# 4                                       410, 162, 52  1.360583  103.833020

# %%
shops_df = pd.read_csv('data/shops_address.csv')
shops_df = shops_df.drop(shops_df.columns[0], axis=1)
shops_df.head()
# Out:
#   licence_numbers            business_name  \
# 0      B02008E000  SHENG SIONG SUPERMARKET
# 1      B02011P000                    GIANT
# 2      B02012N000             COLD STORAGE
# 3      B02015J000  SHENG SIONG SUPERMARKET
# 4      B02017C000  SHENG SIONG SUPERMARKET
#
#                          name_of_license  \
# 0        SHENG SIONG SUPERMARKET PTE LTD
# 1  COLD STORAGE SINGAPORE (1983) PTE LTD
# 2  COLD STORAGE SINGAPORE (1983) PTE LTD
# 3        SHENG SIONG SUPERMARKET PTE LTD
# 4        SHENG SIONG SUPERMARKET PTE LTD
#
#                                      premise_address  \
# 0            845 YISHUN STREET 81 #01-184, S(760845)
# 1  524A JELAPANG ROAD #03-13/18, GREENRIDGE SHOPP...
# 2  768 WOODLANDS AVENUE 6 #01-34, WOODLANDS MART ...
# 3  122 ANG MO KIO AVENUE 3 #01-1753,#01-1757,#01-...
# 4         301 WOODLANDS STREET 31 #01-217, S(730301)
#
#             trimmed_address  latitude   longitude
# 0     845 YISHUN STREET 81   1.416079  103.835019
# 1       524A JELAPANG ROAD   1.385296  103.766171
# 2   768 WOODLANDS AVENUE 6   1.445718  103.798166
# 3  122 ANG MO KIO AVENUE 3   1.370189  103.843413
# 4  301 WOODLANDS STREET 31   1.431505  103.773516

# %%
import requests
import os
      
url = "https://www.onemap.gov.sg/api/auth/post/getToken"
      
payload = {
        "email": '23jkkrithika@gmail.com',
        "password": 'oneMapapi2322'
      }
      
response = requests.request("POST", url, json=payload)
      
print(response.text)
# Out:
# {
#   "access_token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..v1UhAKQFruyhqL0Mn84-Og9Zkmn5V4c8ezLURodD8xg",
#   "expiry_timestamp": "1725819457"
# }

# %%
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.._Pg0RLUT76zfwUAQlUWCa6-ZYuuKmKsDGZXmYbEof9g'

# %%
import requests

# headers = {
#         'Authorization': api_key  # Use the api_key variable here
#     }
    
url = "https://www.onemap.gov.sg/api/common/elastic/search?searchVal=524A JELAPANG ROAD&returnGeom=Y&getAddrDetails=Y&pageNum=1"
# url = "https://www.onemap.gov.sg/api/public/routingsvc/route?start=1.319728%2C103.8421&end=1.319728905%2C103.8421581&routeType=walk"

response = requests.get(url)
# response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {
#   "found": 5,
#   "totalNumPages": 1,
#   "pageNum": 1,
#   "results": [
#     {
#       "SEARCHVAL": "AMAZING STAR MONTESSORI HOUSE (GREENRIDGE)",
#       "BLK_NO": "524A",
#       "ROAD_NAME": "JELAPANG ROAD",
#       "BUILDING": "AMAZING STAR MONTESSORI HOUSE (GREENRIDGE)",
#       "ADDRESS": "524A JELAPANG ROAD AMAZING STAR MONTESSORI HOUSE (GREENRIDGE) SINGAPORE 671524",
#       "POSTAL": "671524",
#       "X": "20527.2820040528",
#       "Y": "40804.5665046293",
#       "LATITUDE": "1.38529556252963",
#       "LONGITUDE": "103.766170532051"
#     },
#     {
#       "SEARCHVAL": "DBS GREENRIDGE SHOPPING CENTRE",
#       "BLK_NO": "524A",
#       "ROAD_NAME": "JELAPANG ROAD",
#       "BUILDING": "DBS GREENRIDGE SHOPPING CENTRE",
#       "ADDRESS": "524A JELAPANG ROAD DBS GREENRIDGE SHOPPING CENTRE SINGAPORE 671524",
#       "POSTAL": "671524",
#       "X": "20527.2817921769",
#       "Y": "40804.5668073092",
#       "LATITUDE": "1.38529556526689",
#       "LONGITUDE": "103.766170530147"
#     },
#     {
#       "SEARCHVAL": "GREENRIDGE SHOPPING CENTRE",
#       "BLK_NO": "524A",
#       "ROAD_NAME": "JELAPANG ROAD",
#       "BUILDING": "GREENRIDGE SHOPPING CENTRE",
#       "ADDRESS": "524A JELAPANG ROAD GREENRIDGE SHOPPING CENTRE SINGAPORE 671524",
#       "POSTAL": "671524",
#       "X": "20533.7299018195",
#       "Y": "40816.7439803742",
#       "LATITUDE": "1.38540569283271",
#       "LONGITUDE": "103.766228468185"
#     },
#     {
#       "SEARCHVAL": "OCBC GREENRIDGE SHOPPING CENTRE",
#       "BLK_NO": "524A",
#       "ROAD_NAME": "JELAPANG ROAD",
#       "BUILDING": "OCBC GREENRIDGE SHOPPING CENTRE",
#       "ADDRESS": "524A JELAPANG ROAD OCBC GREENRIDGE SHOPPING CENTRE SINGAPORE 671524",
#       "POSTAL": "671524",
#       "X": "20533.7299018195",
#       "Y": "40816.7440106422",
#       "LATITUDE": "1.38540569310644",
#       "LONGITUDE": "103.766228468185"
#     },
#     {
#       "SEARCHVAL": "UOB GREENRIDGE SHOPPING CENTRE",
#       "BLK_NO": "524A",
#       "ROAD_NAME": "JELAPANG ROAD",
#       "BUILDING": "UOB GREENRIDGE SHOPPING CENTRE",
#       "ADDRESS": "524A JELAPANG ROAD UOB GREENRIDGE SHOPPING CENTRE SINGAPORE 671524",
#       "POSTAL": "671524",
#       "X": "20533.7299018195",
#       "Y": "40816.7440106422",
#       "LATITUDE": "1.38540569310644",
#       "LONGITUDE": "103.766228468185"
#     }
#   ]
# }

# %%
import requests

# Block number and road name to search
blk_no = "309"
road_name = "ANG MO KIO AVENUE 1"

# Combine block number and road name to form the search value
search_val = f"{blk_no} {road_name}"

# Encode the search value for the URL
encoded_search_val = requests.utils.quote(search_val)

# Construct the URL
url = f"https://www.onemap.gov.sg/api/common/elastic/search?searchVal={encoded_search_val}&returnGeom=Y&getAddrDetails=Y&pageNum=1"

# Send the GET request
response = requests.get(url)

# Parse the JSON response
response_data = response.json()

# Check if the search returned any results
if 'results' in response_data and response_data['results']:
    # Iterate through the results and print details
    for result in response_data['results']:
        blk_no = result.get('BLK_NO', 'N/A')
        road_name = result.get('ROAD_NAME', 'N/A')
        building_name = result.get('BUILDING', 'N/A')
        address = result.get('ADDRESS', 'N/A')
        postal_code = result.get('POSTAL', 'N/A')
        latitude = result.get('LATITUDE', 'N/A')
        longitude = result.get('LONGITUDE', 'N/A')
        
        print(f"Block No: {blk_no}")
        print(f"Road Name: {road_name}")
        print(f"Building: {building_name}")
        print(f"Address: {address}")
        print(f"Postal Code: {postal_code}")
        print(f"Latitude: {latitude}")
        print(f"Longitude: {longitude}")
        print("-" * 50)
else:
    print("No results found.")
# Out:
# Block No: 215
# Road Name: ANG MO KIO AVENUE 1
# Building: ANG MO KIO 22
# Address: 215 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPORE 560215
# Postal Code: 560215
# Latitude: 1.36655830166122
# Longitude: 103.841624082978
# --------------------------------------------------
# Block No: 216
# Road Name: ANG MO KIO AVENUE 1
# Building: ANG MO KIO 22
# Address: 216 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPORE 560216
# Postal Code: 560216
# Latitude: 1.36619678831054
# Longitude: 103.841505011903
# --------------------------------------------------
# Block No: 57
# Road Name: ANG MO KIO AVENUE 8
# Building: ANG MO KIO BUS INTERCHANGE
# Address: 57 ANG MO KIO AVENUE 8 ANG MO KIO BUS INTERCHANGE SINGAPORE 567751
# Postal Code: 567751
# Latitude: 1.36951942637994
# Longitude: 103.848462230319
# --------------------------------------------------
# Block No: 2874
# Road Name: ANG MO KIO AVENUE 9
# Building: ANG MO KIO FIRE STATION
# Address: 2874 ANG MO KIO AVENUE 9 ANG MO KIO FIRE STATION SINGAPORE 569783
# Postal Code: 569783
# Latitude: 1.3849878525885
# Longitude: 103.845627324406
# --------------------------------------------------
# Block No: 218
# Road Name: ANG MO KIO AVENUE 1
# Building: ANG MO KIO GROVE
# Address: 218 ANG MO KIO AVENUE 1 ANG MO KIO GROVE SINGAPORE 560218
# Postal Code: 560218
# Latitude: 1.36511908595886
# Longitude: 103.841742478489
# --------------------------------------------------
# Block No: 2450
# Road Name: ANG MO KIO AVENUE 8
# Building: ANG MO KIO MRT STATION
# Address: 2450 ANG MO KIO AVENUE 8 ANG MO KIO MRT STATION SINGAPORE 569811
# Postal Code: 569811
# Latitude: 1.36993284962264
# Longitude: 103.849558091776
# --------------------------------------------------
# Block No: 2795
# Road Name: ANG MO KIO AVENUE 8
# Building: ANG MO KIO MRT STATION (NS16)
# Address: 2795 ANG MO KIO AVENUE 8 ANG MO KIO MRT STATION (NS16) SINGAPORE 569812
# Postal Code: 569812
# Latitude: 1.36993284962262
# Longitude: 103.84955809232
# --------------------------------------------------
# Block No: 25
# Road Name: ANG MO KIO AVENUE 1
# Building: ANG MO KIO TELEPHONE EXCHANGE
# Address: 25 ANG MO KIO AVENUE 1 ANG MO KIO TELEPHONE EXCHANGE SINGAPORE 569969
# Postal Code: 569969
# Latitude: 1.3682083949841
# Longitude: 103.829987317876
# --------------------------------------------------
# Block No: 793
# Road Name: ANG MO KIO AVENUE 1
# Building: SPC ANG MO KIO AVENUE 1 (1)
# Address: 793 ANG MO KIO AVENUE 1 SPC ANG MO KIO AVENUE 1 (1) SINGAPORE 569975
# Postal Code: 569975
# Latitude: 1.36544473560131
# Longitude: 103.839573124991
# --------------------------------------------------
# Block No: 1351
# Road Name: ANG MO KIO AVENUE 1
# Building: SPC ANG MO KIO AVENUE 1 (2)
# Address: 1351 ANG MO KIO AVENUE 1 SPC ANG MO KIO AVENUE 1 (2) SINGAPORE 569977
# Postal Code: 569977
# Latitude: 1.3643623904789
# Longitude: 103.846004854819
# --------------------------------------------------

# %%
hdb_df2 = hdb_df[:100]

# %%
# def get_nearest_mrt(lat, lon):
#     url = f"https://www.onemap.gov.sg/api/public/routingsvc/route?start={lat},{lon}&end={lat+0.01},{lon+0.01}&routeType=pt&mode=TRANSIT&maxWalkDistance=1000&numItineraries=1"
    
#     headers = {
#         'Authorization': api_key  # Use the api_key variable here
#     }
    
#     response = requests.get(url, headers=headers)
    
#     if response.status_code == 200:
#         data = response.json()
#         if data['plan']['itineraries']:
#             nearest_mrt = data['plan']['itineraries'][0]['legs'][0]['to']['name']
#             return nearest_mrt
#         else:
#             return None
#     else:
#         print(f"Error: {response.status_code}")
#         return None

# # Apply the function to each row in the DataFrame with progress tracking
# tqdm.pandas(desc="Processing HDB locations")
# hdb_df2['nearest_mrt'] = hdb_df2.progress_apply(lambda row: get_nearest_mrt(row['latitude'], row['longitude']), axis=1)

# %%
from geopy.distance import geodesic
from tqdm import tqdm

# Create empty columns in hdb_df to store the results
hdb_df2['nearest_shop_name'] = ''
hdb_df2['nearest_shop_distance'] = 0.0
hdb_df2['nearest_shop_latitude'] = 0.0
hdb_df2['nearest_shop_longitude'] = 0.0

# Iterate over each HDB location
for index, hdb_row in tqdm(hdb_df2.iterrows(), total=hdb_df2.shape[0], desc="Processing HDB shop distance"):
    hdb_coord = (hdb_row['latitude'], hdb_row['longitude'])
    
    # Calculate distance to each shop
    distances = [
        (geodesic(hdb_coord, (shop_row['latitude'], shop_row['longitude'])).meters, 
         shop_row['business_name'], 
         shop_row['latitude'], 
         shop_row['longitude'])
        for _, shop_row in shops_df.iterrows()
    ]
    
    # Find the minimum distance and corresponding shop details
    min_distance, nearest_shop_name, shop_latitude, shop_longitude = min(distances, key=lambda x: x[0])
    
    # Update the hdb_df with the nearest shop details
    hdb_df2.at[index, 'nearest_shop_name'] = nearest_shop_name
    hdb_df2.at[index, 'nearest_shop_distance'] = min_distance
    hdb_df2.at[index, 'nearest_shop_latitude'] = shop_latitude
    hdb_df2.at[index, 'nearest_shop_longitude'] = shop_longitude
# Out:
# C:\Users\Krithika JK\AppData\Local\Temp\ipykernel_11860\2877403215.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb_df2['nearest_shop_name'] = ''
# C:\Users\Krithika JK\AppData\Local\Temp\ipykernel_11860\2877403215.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb_df2['nearest_shop_distance'] = 0.0
# C:\Users\Krithika JK\AppData\Local\Temp\ipykernel_11860\2877403215.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb_df2['nearest_shop_latitude'] = 0.0
# C:\Users\Krithika JK\AppData\Local\Temp\ipykernel_11860\2877403215.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdb_df2['nearest_shop_longitude'] = 0.0
# Processing HDB shop distance: 100%|██████████████████████████████████████████████████| 100/100 [00:24<00:00,  4.05it/s]

# %%
hdb_df2.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#   remaining_lease               address  latitude   longitude  year  \
# 0             NaN  309 ANG MO KIO AVE 1  1.366558  103.841624  1990
# 1             NaN  309 ANG MO KIO AVE 1  1.366558  103.841624  1990
# 2             NaN  309 ANG MO KIO AVE 1  1.366558  103.841624  1990
# 3             NaN  309 ANG MO KIO AVE 1  1.366558  103.841624  1990
# 4             NaN  216 ANG MO KIO AVE 1  1.366197  103.841505  1990
#
#   nearest_shop_name  nearest_shop_distance  nearest_shop_latitude  \
# 0         FAIRPRICE               0.000000               1.366558
# 1         FAIRPRICE               0.000000               1.366558
# 2         FAIRPRICE               0.000000               1.366558
# 3         FAIRPRICE               0.000000               1.366558
# 4         FAIRPRICE              42.113407               1.366558
#
#    nearest_shop_longitude
# 0              103.841624
# 1              103.841624
# 2              103.841624
# 3              103.841624
# 4              103.841624

# %%
# Filter shops_df for rows where trimmed_address contains 'ANG MO KIO' and business_name is 'FAIRPRICE'
filtered_shops = shops_df[
    (shops_df['trimmed_address'].str.contains('ANG MO KIO', case=False, na=False)) &
    (shops_df['business_name'] == 'FAIRPRICE')
]

# Display the filtered rows
filtered_shops.head()
# Out:
#    licence_numbers business_name                  name_of_license  \
# 26      B98014C000     FAIRPRICE  NTUC FAIRPRICE CO-OPERATIVE LTD
# 87     CE11N90C000     FAIRPRICE  NTUC FAIRPRICE CO-OPERATIVE LTD
#
#                                 premise_address           trimmed_address  \
# 26   215 ANG MO KIO AVENUE 1 #01-877, S(560215)  215 ANG MO KIO AVENUE 1
# 87  712 ANG MO KIO AVENUE 6 #01-4056, S(560712)  712 ANG MO KIO AVENUE 6
#
#     latitude   longitude
# 26  1.366558  103.841624
# 87  1.371411  103.847084

# %%
# list_of_lat = hdb_df2['latitude']
# list_of_long = hdb_df2['longitude']
# shops_lat = shops_df['latitude']
# shops_long = shops_df['longitude']

# %%
# list_of_hdb_coordinates = []
# list_of_shops_coordinates = []

# for lat, long in zip(list_of_lat, list_of_long):
#     list_of_hdb_coordinates.append((lat,long))
# for lat, long in zip(shops_lat, shops_long):
#     list_of_shops_coordinates.append((lat, long))

# %%
# # Distance to nearest shop
# from geopy.distance import geodesic

# list_of_dist_shops = []
# min_dist_shops = []

# tqdm.pandas(desc="Processing HDB shop distance")
# for origin in list_of_hdb_coordinates:
#     for destination in range(0, len(list_of_shops_coordinates)):
#         list_of_dist_shops.append(geodesic(origin,list_of_shops_coordinates[destination]).meters)
#     shortest = (min(list_of_dist_shops))
#     min_dist_shops.append(shortest)
#     list_of_dist_shops.clear()

# %%
# # Distance from CDB
# cbd_dist = []

# for origin in list_of_coordinates:
#     cbd_dist.append(geodesic(origin,(1.2830, 103.8513)).meters) #CBD coordinates

# %%
# # Put MRT and CBD distance together
# # df_coordinates['cbd_dist'] = cbd_dist
# hdb_df2['min_dist_shops'] = min_dist_shops

# %%
print(min_dist_shops)

# %%
hawker_df = pd.read_csv('data/hawkers_address.csv')
hawker_df.head()
# Out:
#             name_of_centre                                 location_of_centre  \
# 0    Adam Road Food Centre                            2, Adam Road, S(289876)
# 1  Amoy Street Food Centre  National Development Building, Annex B, Telok ...
# 2        Bedok Food Centre                           1, Bedok Road, S(469572)
# 3      Beo Crescent Market                       38A, Beo Crescent, S(169982)
# 4       Berseh Food Centre                        166, Jalan Besar, S(208877)
#
#   type_of_centre       owner  no_of_stalls  no_of_cooked_food_stalls  \
# 0             HC  Government            32                        32
# 1             HC  Government           135                       134
# 2             HC  Government            32                        32
# 3            MHC  Government            94                        32
# 4             HC  Government            66                        66
#
#    no_of_mkt_produce_stalls  latitude   longitude
# 0                         0  1.324083  103.814182
# 1                         1  1.279340  103.846652
# 2                         0  1.320347  103.955481
# 3                        62  1.288831  103.827354
# 4                         0  1.307344  103.856889

# %%
mrt_df = pd.read_csv('data/mrt_address.csv')
mrt_df.head()
# Out:
#   station_code  latitude   longitude                          station_name
# 0          NS1  1.333153  103.742286  JURONG EAST MRT STATION (EW24 / NS1)
# 1          NS2  1.349033  103.749566         BUKIT BATOK MRT STATION (NS2)
# 2          NS3  1.358612  103.751791        BUKIT GOMBAK MRT STATION (NS3)
# 3          NS4  1.385363  103.744371       CHOA CHU KANG MRT STATION (NS4)
# 4          NS5  1.397535  103.747405             YEW TEE MRT STATION (NS5)
